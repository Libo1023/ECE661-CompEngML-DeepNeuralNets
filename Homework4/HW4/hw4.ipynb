# %% [markdown]
# ### Lab2 (a) Model preperation

# %%
from resnet20 import ResNetCIFAR
from train_util import train, finetune, test
import torch
import numpy as np

import time

import torchvision.transforms as transforms
import torchvision
import torch.nn as nn
import torch.optim as optim

from FP_layers import *

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
net = ResNetCIFAR(num_layers=20, Nbits=None)
net = net.to(device)

# %%
# Load the best weight paramters
net.load_state_dict(torch.load("pretrained_model.pt"))
test(net)
# Out:
# Files already downloaded and verified
# Test Loss=0.3231, Test accuracy=0.9151

# %% [markdown]
# ### Lab2 (b) Prune by percentage

# %%
def prune_by_percentage(layer, q=80.0):
    """
    Pruning the weight paramters by threshold.
    :param q: pruning percentile. 'q' percent of the least 
    significant weight parameters will be pruned.
    """
    # Convert the weight of "layer" to numpy array
    np_weight = layer.weight.detach().cpu().numpy()
    # Compute the q-th percentile of the abs of the converted array
    weight_abs = np.absolute(np_weight)
    qth_percentile = np.percentile(weight_abs, q)
    # Generate a binary mask same shape as weight to decide which element to prune
    binary_mask = weight_abs > qth_percentile
    # Convert mask to torch tensor and put on GPU
    mask_tensor = torch.from_numpy(binary_mask).float().to(device)
    # Multiply the weight by mask to perform pruning
    layer.weight.data = layer.weight.data * mask_tensor
    #print(layer.weight.data)
    #pass

# %%
net.load_state_dict(torch.load("pretrained_model.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # change q value
        #prune_by_percentage(layer, q = 40.0)
        #prune_by_percentage(layer, q = 60.0)
        prune_by_percentage(layer, q = 80.0)
        
        # Optional: Check the sparsity you achieve in each layer
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.detach().cpu().numpy()
        # Count number of zeros
        zeros = np_weight.size - np.count_nonzero(np_weight)
        # Count number of parameters
        total = np_weight.size
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.7986111111111112
# Sparsity of body_op.0.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.0.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.4.conv1.0.conv: 0.8000217013888888
# Sparsity of body_op.4.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.5.conv1.0.conv: 0.8000217013888888
# Sparsity of body_op.5.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.6.conv1.0.conv: 0.7999674479166666
# Sparsity of body_op.6.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv2.0.conv: 0.7999945746527778
# Sparsity of final_fc.linear: 0.8
# Files already downloaded and verified
# Test Loss=6.3235, Test accuracy=0.1003

# %% [markdown]
# ### Lab2 (c) Finetune pruned model

# %%
def finetune_after_prune(net, trainloader, criterion, optimizer, prune=True):
    """
    Finetune the pruned model for a single epoch
    Make sure pruned weights are kept as zero
    """
    # Build a dictionary for the nonzero weights
    weight_mask = {}
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Your code here: generate a mask in GPU torch tensor to have 1 for nonzero element and 0 for zero element
            weight_mask[name] = layer.weight.data != 0.0
            #print(weight_mask[name])      
    
    
    global_steps = 0
    train_loss = 0
    correct = 0
    total = 0
    start = time.time()
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        
        if prune:
            for name,layer in net.named_modules():
                if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
                    # Your code here: Use weight_mask to make sure zero elements remains zero
                    layer.weight.data = layer.weight.data * weight_mask[name]
                    #print(layer.weight.data)
                    
        
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        global_steps += 1

        if global_steps % 50 == 0:
            end = time.time()
            num_examples_per_second = 50 * batch_size / (end - start)
            print("[Step=%d]\tLoss=%.4f\tacc=%.4f\t%.1f examples/second"
                 % (global_steps, train_loss / (batch_idx + 1), (correct / total), num_examples_per_second))
            start = time.time()

# %%
# Get pruned model
net.load_state_dict(torch.load("pretrained_model.pt"))
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        prune_by_percentage(layer, q=80.0)

# Training setup, do not change
batch_size=256
lr=0.002
reg=1e-4

print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=16)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.875, weight_decay=reg, nesterov=False)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# C:\Users\Administrator\anaconda3\envs\pytorch\lib\site-packages\torch\utils\data\dataloader.py:477: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12 (`cpuset` is not taken into account), which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified

# %%
# Model finetuning
for epoch in range(20): 
    print('\nEpoch: %d' % epoch)
    net.train()
    finetune_after_prune(net, trainloader, criterion, optimizer)
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))

    if val_acc > best_acc:
        best_acc = val_acc
        print("Saving...")
        torch.save(net.state_dict(), "net_after_finetune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.9905	acc=0.6847	540.0 examples/second
# [Step=100]	Loss=0.8140	acc=0.7357	4869.5 examples/second
# [Step=150]	Loss=0.7257	acc=0.7626	4852.8 examples/second
# Test Loss=0.5564, Test acc=0.8182
# Saving...
#
# Epoch: 1
# [Step=50]	Loss=0.4625	acc=0.8458	539.3 examples/second
# [Step=100]	Loss=0.4588	acc=0.8461	4871.8 examples/second
# [Step=150]	Loss=0.4538	acc=0.8464	4859.1 examples/second
# Test Loss=0.4851, Test acc=0.8388
# Saving...
#
# Epoch: 2
# [Step=50]	Loss=0.4149	acc=0.8596	542.1 examples/second
# [Step=100]	Loss=0.4046	acc=0.8629	4857.9 examples/second
# [Step=150]	Loss=0.3969	acc=0.8652	4851.6 examples/second
# Test Loss=0.4536, Test acc=0.8506
# Saving...
#
# Epoch: 3
# [Step=50]	Loss=0.3714	acc=0.8748	547.1 examples/second
# [Step=100]	Loss=0.3704	acc=0.8744	4844.9 examples/second
# [Step=150]	Loss=0.3644	acc=0.8747	4852.8 examples/second
# Test Loss=0.4347, Test acc=0.8573
# Saving...
#
# Epoch: 4
# [Step=50]	Loss=0.3479	acc=0.8787	543.3 examples/second
# [Step=100]	Loss=0.3468	acc=0.8803	4848.0 examples/second
# [Step=150]	Loss=0.3421	acc=0.8825	4839.1 examples/second
# Test Loss=0.4210, Test acc=0.8622
# Saving...
#
# Epoch: 5
# [Step=50]	Loss=0.3262	acc=0.8888	568.6 examples/second
# [Step=100]	Loss=0.3238	acc=0.8896	4850.7 examples/second
# [Step=150]	Loss=0.3238	acc=0.8884	4845.2 examples/second
# Test Loss=0.4121, Test acc=0.8642
# Saving...
#
# Epoch: 6
# [Step=50]	Loss=0.3118	acc=0.8916	537.6 examples/second
# [Step=100]	Loss=0.3192	acc=0.8889	4829.5 examples/second
# [Step=150]	Loss=0.3165	acc=0.8902	4847.1 examples/second
# Test Loss=0.4051, Test acc=0.8657
# Saving...
#
# Epoch: 7
# [Step=50]	Loss=0.3071	acc=0.8933	538.8 examples/second
# [Step=100]	Loss=0.3003	acc=0.8960	4824.4 examples/second
# [Step=150]	Loss=0.2982	acc=0.8971	4835.6 examples/second
# Test Loss=0.3998, Test acc=0.8667
# Saving...
#
# Epoch: 8
# [Step=50]	Loss=0.2899	acc=0.9037	537.8 examples/second
# [Step=100]	Loss=0.2964	acc=0.8989	4827.1 examples/second
# [Step=150]	Loss=0.2969	acc=0.8980	4809.7 examples/second
# Test Loss=0.3930, Test acc=0.8676
# Saving...
#
# Epoch: 9
# [Step=50]	Loss=0.2830	acc=0.9041	569.9 examples/second
# [Step=100]	Loss=0.2886	acc=0.9012	4848.5 examples/second
# [Step=150]	Loss=0.2846	acc=0.9018	4854.4 examples/second
# Test Loss=0.3893, Test acc=0.8696
# Saving...
#
# Epoch: 10
# [Step=50]	Loss=0.2850	acc=0.9010	496.9 examples/second
# [Step=100]	Loss=0.2845	acc=0.9002	4822.0 examples/second
# [Step=150]	Loss=0.2817	acc=0.9026	4843.5 examples/second
# Test Loss=0.3842, Test acc=0.8715
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=0.2815	acc=0.9055	537.7 examples/second
# [Step=100]	Loss=0.2853	acc=0.9021	4834.6 examples/second
# [Step=150]	Loss=0.2777	acc=0.9048	4799.0 examples/second
# Test Loss=0.3809, Test acc=0.8733
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.2706	acc=0.9057	553.4 examples/second
# [Step=100]	Loss=0.2653	acc=0.9081	4831.2 examples/second
# [Step=150]	Loss=0.2649	acc=0.9083	4831.2 examples/second
# Test Loss=0.3784, Test acc=0.8740
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=0.2596	acc=0.9134	547.5 examples/second
# [Step=100]	Loss=0.2611	acc=0.9116	4844.9 examples/second
# [Step=150]	Loss=0.2614	acc=0.9104	4830.4 examples/second
# Test Loss=0.3765, Test acc=0.8746
# Saving...
#
# Epoch: 14
# [Step=50]	Loss=0.2676	acc=0.9059	567.5 examples/second
# [Step=100]	Loss=0.2650	acc=0.9079	4842.9 examples/second
# [Step=150]	Loss=0.2624	acc=0.9092	4844.2 examples/second
# Test Loss=0.3739, Test acc=0.8754
# Saving...
#
# Epoch: 15
# [Step=50]	Loss=0.2486	acc=0.9140	568.5 examples/second
# [Step=100]	Loss=0.2515	acc=0.9131	4841.9 examples/second
# [Step=150]	Loss=0.2532	acc=0.9125	4846.4 examples/second
# Test Loss=0.3727, Test acc=0.8759
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=0.2602	acc=0.9091	541.8 examples/second
# [Step=100]	Loss=0.2564	acc=0.9089	4829.2 examples/second
# [Step=150]	Loss=0.2546	acc=0.9102	4835.9 examples/second
# Test Loss=0.3698, Test acc=0.8767
# Saving...
#
# Epoch: 17
# [Step=50]	Loss=0.2536	acc=0.9121	546.6 examples/second
# [Step=100]	Loss=0.2484	acc=0.9134	4837.0 examples/second
# [Step=150]	Loss=0.2481	acc=0.9135	4846.0 examples/second
# Test Loss=0.3684, Test acc=0.8772
# Saving...
#
# Epoch: 18
# [Step=50]	Loss=0.2450	acc=0.9137	561.2 examples/second
# [Step=100]	Loss=0.2452	acc=0.9136	4830.0 examples/second
# [Step=150]	Loss=0.2418	acc=0.9158	4828.8 examples/second
# Test Loss=0.3662, Test acc=0.8784
# Saving...
#
# Epoch: 19
# [Step=50]	Loss=0.2455	acc=0.9160	562.6 examples/second
# [Step=100]	Loss=0.2460	acc=0.9148	4845.8 examples/second
# [Step=150]	Loss=0.2444	acc=0.9158	4836.4 examples/second
# Test Loss=0.3658, Test acc=0.8790
# Saving...

# %%
# Check sparsity of the finetuned model, make sure it's not changed
net.load_state_dict(torch.load("net_after_finetune.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here:
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.detach().cpu().numpy()
        # Count number of zeros
        zeros = np_weight.size - np.count_nonzero(np_weight)
        # Count number of parameters
        total = np_weight.size
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.7986111111111112
# Sparsity of body_op.0.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.0.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.4.conv1.0.conv: 0.8000217013888888
# Sparsity of body_op.4.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.5.conv1.0.conv: 0.8000217013888888
# Sparsity of body_op.5.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.6.conv1.0.conv: 0.7999674479166666
# Sparsity of body_op.6.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv2.0.conv: 0.7999945746527778
# Sparsity of final_fc.linear: 0.8
# Files already downloaded and verified
# Test Loss=0.3658, Test accuracy=0.8790

# %% [markdown]
# ### Lab2 (d) Iterative pruning

# %%
net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):    
    print('\nEpoch: %d' % epoch)
    
    net.train()
    if epoch<10:
        for name,layer in net.named_modules():
            if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
                # Increase model sparsity
                q = 8.0 * (epoch + 1)
                prune_by_percentage(layer, q=q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer)
    
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))
    
    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "net_after_iterative_prune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.0489	acc=0.9845	524.7 examples/second
# [Step=100]	Loss=0.0481	acc=0.9849	4798.2 examples/second
# [Step=150]	Loss=0.0482	acc=0.9847	4745.0 examples/second
# Test Loss=0.3252, Test acc=0.9143
#
# Epoch: 1
# [Step=50]	Loss=0.0485	acc=0.9848	476.4 examples/second
# [Step=100]	Loss=0.0487	acc=0.9838	4814.2 examples/second
# [Step=150]	Loss=0.0499	acc=0.9835	4773.4 examples/second
# Test Loss=0.3244, Test acc=0.9157
#
# Epoch: 2
# [Step=50]	Loss=0.0539	acc=0.9819	521.4 examples/second
# [Step=100]	Loss=0.0519	acc=0.9831	4837.5 examples/second
# [Step=150]	Loss=0.0531	acc=0.9823	4819.9 examples/second
# Test Loss=0.3291, Test acc=0.9130
#
# Epoch: 3
# [Step=50]	Loss=0.0582	acc=0.9802	553.9 examples/second
# [Step=100]	Loss=0.0565	acc=0.9812	4826.4 examples/second
# [Step=150]	Loss=0.0572	acc=0.9809	4812.1 examples/second
# Test Loss=0.3344, Test acc=0.9115
#
# Epoch: 4
# [Step=50]	Loss=0.0704	acc=0.9759	527.0 examples/second
# [Step=100]	Loss=0.0677	acc=0.9770	4827.9 examples/second
# [Step=150]	Loss=0.0690	acc=0.9761	4824.3 examples/second
# Test Loss=0.3347, Test acc=0.9086
#
# Epoch: 5
# [Step=50]	Loss=0.0906	acc=0.9681	549.5 examples/second
# [Step=100]	Loss=0.0906	acc=0.9688	4830.0 examples/second
# [Step=150]	Loss=0.0862	acc=0.9704	4832.3 examples/second
# Test Loss=0.3356, Test acc=0.9056
#
# Epoch: 6
# [Step=50]	Loss=0.1298	acc=0.9541	555.9 examples/second
# [Step=100]	Loss=0.1245	acc=0.9551	4837.8 examples/second
# [Step=150]	Loss=0.1196	acc=0.9573	4834.5 examples/second
# Test Loss=0.3380, Test acc=0.9009
#
# Epoch: 7
# [Step=50]	Loss=0.1905	acc=0.9321	549.1 examples/second
# [Step=100]	Loss=0.1776	acc=0.9374	4841.5 examples/second
# [Step=150]	Loss=0.1685	acc=0.9412	4824.4 examples/second
# Test Loss=0.3506, Test acc=0.8927
#
# Epoch: 8
# [Step=50]	Loss=0.2812	acc=0.9015	446.6 examples/second
# [Step=100]	Loss=0.2558	acc=0.9106	4810.4 examples/second
# [Step=150]	Loss=0.2473	acc=0.9138	4804.2 examples/second
# Test Loss=0.3715, Test acc=0.8820
#
# Epoch: 9
# [Step=50]	Loss=0.5736	acc=0.8063	555.2 examples/second
# [Step=100]	Loss=0.5169	acc=0.8238	4834.6 examples/second
# [Step=150]	Loss=0.4829	acc=0.8366	4814.9 examples/second
# Test Loss=0.4783, Test acc=0.8453
#
# Epoch: 10
# [Step=50]	Loss=0.3852	acc=0.8694	556.2 examples/second
# [Step=100]	Loss=0.3735	acc=0.8729	4827.5 examples/second
# [Step=150]	Loss=0.3714	acc=0.8742	4830.1 examples/second
# Test Loss=0.4443, Test acc=0.8569
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=0.3416	acc=0.8843	553.0 examples/second
# [Step=100]	Loss=0.3403	acc=0.8849	4828.4 examples/second
# [Step=150]	Loss=0.3377	acc=0.8852	4819.6 examples/second
# Test Loss=0.4236, Test acc=0.8629
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.3333	acc=0.8866	554.5 examples/second
# [Step=100]	Loss=0.3249	acc=0.8889	4822.8 examples/second
# [Step=150]	Loss=0.3221	acc=0.8896	4822.6 examples/second
# Test Loss=0.4144, Test acc=0.8660
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=0.3114	acc=0.8940	555.9 examples/second
# [Step=100]	Loss=0.3088	acc=0.8943	4830.1 examples/second
# [Step=150]	Loss=0.3031	acc=0.8969	4832.6 examples/second
# Test Loss=0.4032, Test acc=0.8669
# Saving...
#
# Epoch: 14
# [Step=50]	Loss=0.2978	acc=0.8971	556.1 examples/second
# [Step=100]	Loss=0.2932	acc=0.8988	4829.2 examples/second
# [Step=150]	Loss=0.2923	acc=0.8989	4832.0 examples/second
# Test Loss=0.3957, Test acc=0.8686
# Saving...
#
# Epoch: 15
# [Step=50]	Loss=0.2883	acc=0.9018	555.4 examples/second
# [Step=100]	Loss=0.2840	acc=0.9027	4829.7 examples/second
# [Step=150]	Loss=0.2849	acc=0.9015	4841.0 examples/second
# Test Loss=0.3904, Test acc=0.8709
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=0.2820	acc=0.9041	555.8 examples/second
# [Step=100]	Loss=0.2818	acc=0.9043	4838.3 examples/second
# [Step=150]	Loss=0.2810	acc=0.9042	4821.8 examples/second
# Test Loss=0.3876, Test acc=0.8723
# Saving...
#
# Epoch: 17
# [Step=50]	Loss=0.2654	acc=0.9066	551.1 examples/second
# [Step=100]	Loss=0.2694	acc=0.9066	4842.0 examples/second
# [Step=150]	Loss=0.2705	acc=0.9065	4808.5 examples/second
# Test Loss=0.3828, Test acc=0.8737
# Saving...
#
# Epoch: 18
# [Step=50]	Loss=0.2610	acc=0.9133	552.2 examples/second
# [Step=100]	Loss=0.2662	acc=0.9091	4822.6 examples/second
# [Step=150]	Loss=0.2620	acc=0.9101	4818.1 examples/second
# Test Loss=0.3813, Test acc=0.8739
# Saving...
#
# Epoch: 19
# [Step=50]	Loss=0.2609	acc=0.9100	555.8 examples/second
# [Step=100]	Loss=0.2583	acc=0.9114	4825.6 examples/second
# [Step=150]	Loss=0.2593	acc=0.9116	4826.7 examples/second
# Test Loss=0.3771, Test acc=0.8737

# %%
# Check sparsity of the final model, make sure it's 80%
net.load_state_dict(torch.load("net_after_iterative_prune.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here: can copy from previous question
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.detach().cpu().numpy()
        # Count number of zeros
        zeros = np_weight.size - np.count_nonzero(np_weight)
        # Count number of parameters
        total = np_weight.size
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))
        
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.7986111111111112
# Sparsity of body_op.0.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.0.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.4.conv1.0.conv: 0.8000217013888888
# Sparsity of body_op.4.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.5.conv1.0.conv: 0.8000217013888888
# Sparsity of body_op.5.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.6.conv1.0.conv: 0.7999674479166666
# Sparsity of body_op.6.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv2.0.conv: 0.7999945746527778
# Sparsity of final_fc.linear: 0.8
# Files already downloaded and verified
# Test Loss=0.3813, Test accuracy=0.8739

# %% [markdown]
# ### Lab2 (e) Global iterative pruning

# %%
def global_prune_by_percentage(net, q=80.0):
    """
    Pruning the weight paramters by threshold.
    :param q: pruning percentile. 'q' percent of the least 
    significant weight parameters will be pruned.
    """
    # A list to gather all the weights
    flattened_weights = []
    # Find global pruning threshold
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Convert weight to numpy
            np_weight = layer.weight.detach().cpu().numpy()
            # Flatten the weight and append to flattened_weights
            flattened_weights.append(np_weight.flatten())
    # Concate all weights into a np array
    flattened_weights = np.concatenate(flattened_weights)
    # Find global pruning threshold
    flattened_weights_abs = np.absolute(flattened_weights)
    thres = np.percentile(flattened_weights_abs, q)
    
    # Apply pruning threshold to all layers
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Convert weight to numpy
            np_weight = layer.weight.detach().cpu().numpy()
            # Generate a binary mask same shape as weight to decide which element to prune
            weight_abs = np.absolute(np_weight)
            binary_mask = weight_abs > thres
            # Convert mask to torch tensor and put on GPU
            mask_tensor = torch.from_numpy(binary_mask).float().to(device)
            # Multiply the weight by mask to perform pruning
            layer.weight.data = layer.weight.data * mask_tensor

# %%
net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    q=(epoch+1)*8
    
    net.train()
    # Increase model sparsity
    if epoch<10:
        global_prune_by_percentage(net, q=q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer)
    
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))
    
    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "net_after_global_iterative_prune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.0516	acc=0.9830	539.8 examples/second
# [Step=100]	Loss=0.0508	acc=0.9833	4835.6 examples/second
# [Step=150]	Loss=0.0503	acc=0.9838	4834.5 examples/second
# Test Loss=0.3227, Test acc=0.9144
#
# Epoch: 1
# [Step=50]	Loss=0.0471	acc=0.9847	540.4 examples/second
# [Step=100]	Loss=0.0470	acc=0.9838	4839.2 examples/second
# [Step=150]	Loss=0.0477	acc=0.9843	4807.8 examples/second
# Test Loss=0.3244, Test acc=0.9147
#
# Epoch: 2
# [Step=50]	Loss=0.0480	acc=0.9852	519.7 examples/second
# [Step=100]	Loss=0.0481	acc=0.9854	4833.1 examples/second
# [Step=150]	Loss=0.0493	acc=0.9845	4819.4 examples/second
# Test Loss=0.3247, Test acc=0.9140
#
# Epoch: 3
# [Step=50]	Loss=0.0546	acc=0.9822	540.2 examples/second
# [Step=100]	Loss=0.0536	acc=0.9829	4820.8 examples/second
# [Step=150]	Loss=0.0539	acc=0.9828	4837.8 examples/second
# Test Loss=0.3260, Test acc=0.9143
#
# Epoch: 4
# [Step=50]	Loss=0.0592	acc=0.9799	559.8 examples/second
# [Step=100]	Loss=0.0609	acc=0.9801	4837.9 examples/second
# [Step=150]	Loss=0.0606	acc=0.9800	4825.9 examples/second
# Test Loss=0.3238, Test acc=0.9128
#
# Epoch: 5
# [Step=50]	Loss=0.0736	acc=0.9741	563.0 examples/second
# [Step=100]	Loss=0.0715	acc=0.9757	4842.6 examples/second
# [Step=150]	Loss=0.0713	acc=0.9760	4826.4 examples/second
# Test Loss=0.3266, Test acc=0.9084
#
# Epoch: 6
# [Step=50]	Loss=0.0905	acc=0.9692	486.5 examples/second
# [Step=100]	Loss=0.0923	acc=0.9684	4826.7 examples/second
# [Step=150]	Loss=0.0922	acc=0.9684	4785.5 examples/second
# Test Loss=0.3264, Test acc=0.9072
#
# Epoch: 7
# [Step=50]	Loss=0.1325	acc=0.9541	561.6 examples/second
# [Step=100]	Loss=0.1266	acc=0.9568	4840.8 examples/second
# [Step=150]	Loss=0.1238	acc=0.9576	4845.7 examples/second
# Test Loss=0.3274, Test acc=0.9018
#
# Epoch: 8
# [Step=50]	Loss=0.2021	acc=0.9309	517.5 examples/second
# [Step=100]	Loss=0.1993	acc=0.9314	4828.8 examples/second
# [Step=150]	Loss=0.1899	acc=0.9346	4834.9 examples/second
# Test Loss=0.3391, Test acc=0.8878
#
# Epoch: 9
# [Step=50]	Loss=0.4076	acc=0.8627	533.9 examples/second
# [Step=100]	Loss=0.3858	acc=0.8693	4776.4 examples/second
# [Step=150]	Loss=0.3714	acc=0.8750	4765.6 examples/second
# Test Loss=0.4228, Test acc=0.8583
#
# Epoch: 10
# [Step=50]	Loss=0.3166	acc=0.8880	532.4 examples/second
# [Step=100]	Loss=0.3069	acc=0.8929	4798.5 examples/second
# [Step=150]	Loss=0.3077	acc=0.8932	4805.3 examples/second
# Test Loss=0.3972, Test acc=0.8667
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=0.2965	acc=0.8967	518.6 examples/second
# [Step=100]	Loss=0.2878	acc=0.9008	4799.6 examples/second
# [Step=150]	Loss=0.2857	acc=0.9026	4809.5 examples/second
# Test Loss=0.3842, Test acc=0.8718
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.2660	acc=0.9121	552.2 examples/second
# [Step=100]	Loss=0.2703	acc=0.9091	4827.8 examples/second
# [Step=150]	Loss=0.2713	acc=0.9083	4802.3 examples/second
# Test Loss=0.3762, Test acc=0.8741
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=0.2643	acc=0.9109	549.5 examples/second
# [Step=100]	Loss=0.2644	acc=0.9104	4813.5 examples/second
# [Step=150]	Loss=0.2620	acc=0.9114	4807.7 examples/second
# Test Loss=0.3680, Test acc=0.8769
# Saving...
#
# Epoch: 14
# [Step=50]	Loss=0.2513	acc=0.9155	539.6 examples/second
# [Step=100]	Loss=0.2533	acc=0.9150	4824.7 examples/second
# [Step=150]	Loss=0.2518	acc=0.9147	4765.5 examples/second
# Test Loss=0.3626, Test acc=0.8778
# Saving...
#
# Epoch: 15
# [Step=50]	Loss=0.2536	acc=0.9187	535.4 examples/second
# [Step=100]	Loss=0.2507	acc=0.9174	4819.5 examples/second
# [Step=150]	Loss=0.2481	acc=0.9169	4821.1 examples/second
# Test Loss=0.3578, Test acc=0.8793
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=0.2407	acc=0.9170	555.9 examples/second
# [Step=100]	Loss=0.2402	acc=0.9172	4804.0 examples/second
# [Step=150]	Loss=0.2403	acc=0.9187	4821.8 examples/second
# Test Loss=0.3560, Test acc=0.8815
# Saving...
#
# Epoch: 17
# [Step=50]	Loss=0.2310	acc=0.9198	543.3 examples/second
# [Step=100]	Loss=0.2321	acc=0.9205	4789.9 examples/second
# [Step=150]	Loss=0.2331	acc=0.9199	4798.5 examples/second
# Test Loss=0.3537, Test acc=0.8825
# Saving...
#
# Epoch: 18
# [Step=50]	Loss=0.2352	acc=0.9245	534.2 examples/second
# [Step=100]	Loss=0.2297	acc=0.9242	4823.2 examples/second
# [Step=150]	Loss=0.2284	acc=0.9235	4820.8 examples/second
# Test Loss=0.3493, Test acc=0.8833
# Saving...
#
# Epoch: 19
# [Step=50]	Loss=0.2186	acc=0.9277	547.5 examples/second
# [Step=100]	Loss=0.2249	acc=0.9256	4824.4 examples/second
# [Step=150]	Loss=0.2237	acc=0.9248	4810.0 examples/second
# Test Loss=0.3465, Test acc=0.8868
# Saving...

# %%
net.load_state_dict(torch.load("net_after_global_iterative_prune.pt"))

zeros_sum = 0
total_sum = 0
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here:
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.detach().cpu().numpy()
        # Count number of zeros
        zeros = np_weight.size - np.count_nonzero(np_weight)
        # Count number of parameters
        total = np_weight.size
        zeros_sum+=zeros
        total_sum+=total
        print('Sparsity of '+name+': '+str(zeros/total))
print('Total sparsity of: '+str(zeros_sum/total_sum))
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.3101851851851852
# Sparsity of body_op.0.conv1.0.conv: 0.6584201388888888
# Sparsity of body_op.0.conv2.0.conv: 0.6380208333333334
# Sparsity of body_op.1.conv1.0.conv: 0.6263020833333334
# Sparsity of body_op.1.conv2.0.conv: 0.6484375
# Sparsity of body_op.2.conv1.0.conv: 0.6315104166666666
# Sparsity of body_op.2.conv2.0.conv: 0.6684027777777778
# Sparsity of body_op.3.conv1.0.conv: 0.6234809027777778
# Sparsity of body_op.3.conv2.0.conv: 0.6884765625
# Sparsity of body_op.4.conv1.0.conv: 0.7259114583333334
# Sparsity of body_op.4.conv2.0.conv: 0.7829861111111112
# Sparsity of body_op.5.conv1.0.conv: 0.7250434027777778
# Sparsity of body_op.5.conv2.0.conv: 0.8133680555555556
# Sparsity of body_op.6.conv1.0.conv: 0.7322591145833334
# Sparsity of body_op.6.conv2.0.conv: 0.7645670572916666
# Sparsity of body_op.7.conv1.0.conv: 0.7769911024305556
# Sparsity of body_op.7.conv2.0.conv: 0.8260633680555556
# Sparsity of body_op.8.conv1.0.conv: 0.8526204427083334
# Sparsity of body_op.8.conv2.0.conv: 0.9766981336805556
# Sparsity of final_fc.linear: 0.1578125
# Total sparsity of: 0.8000007453342078
# Files already downloaded and verified
# Test Loss=0.3465, Test accuracy=0.8868

# %% [markdown]
# ### Lab 3 (b) and (c): Fixed-point quantization

# %%
# Define quantized model and load weight
#Nbits = 6 #Change this value to finish (b) and (c)
#Nbits = 5
#Nbits = 4
#Nbits = 3
Nbits = 2

net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
net = net.to(device)
net.load_state_dict(torch.load("pretrained_model.pt"))
test(net)
# Out:
# Files already downloaded and verified
# Test Loss=9.5441, Test accuracy=0.0899

# %%
# Quantized model finetuning
finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)

# Load the model with best accuracy
net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
test(net)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=1.3516	acc=0.6209	553.7 examples/second
# [Step=100]	Loss=1.0775	acc=0.6842	4752.7 examples/second
# [Step=150]	Loss=0.9499	acc=0.7137	4736.4 examples/second
# Test Loss=0.8030, Test acc=0.7636
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.5760	acc=0.8145	484.2 examples/second
# [Step=250]	Loss=0.5728	acc=0.8101	4758.7 examples/second
# [Step=300]	Loss=0.5673	acc=0.8090	4740.5 examples/second
# [Step=350]	Loss=0.5496	acc=0.8144	4746.9 examples/second
# Test Loss=0.6345, Test acc=0.8066
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.4651	acc=0.8438	491.0 examples/second
# [Step=450]	Loss=0.4782	acc=0.8332	4763.4 examples/second
# [Step=500]	Loss=0.4748	acc=0.8366	4770.4 examples/second
# [Step=550]	Loss=0.4653	acc=0.8394	4762.2 examples/second
# Test Loss=0.6550, Test acc=0.8078
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=0.4282	acc=0.8503	485.5 examples/second
# [Step=650]	Loss=0.4315	acc=0.8515	4762.1 examples/second
# [Step=700]	Loss=0.4279	acc=0.8528	4775.1 examples/second
# [Step=750]	Loss=0.4251	acc=0.8532	4741.7 examples/second
# Test Loss=0.6037, Test acc=0.8120
# Saving...
#
# Epoch: 4
# [Step=800]	Loss=0.4061	acc=0.8567	498.5 examples/second
# [Step=850]	Loss=0.4056	acc=0.8601	4756.4 examples/second
# [Step=900]	Loss=0.4019	acc=0.8603	4755.0 examples/second
# [Step=950]	Loss=0.3956	acc=0.8616	4752.8 examples/second
# Test Loss=0.5313, Test acc=0.8338
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=0.3688	acc=0.8701	483.6 examples/second
# [Step=1050]	Loss=0.3805	acc=0.8681	4754.8 examples/second
# [Step=1100]	Loss=0.3796	acc=0.8665	4756.8 examples/second
# [Step=1150]	Loss=0.3798	acc=0.8669	4755.6 examples/second
# Test Loss=0.6175, Test acc=0.8123
#
# Epoch: 6
# [Step=1200]	Loss=0.3684	acc=0.8683	485.3 examples/second
# [Step=1250]	Loss=0.3690	acc=0.8698	4757.1 examples/second
# [Step=1300]	Loss=0.3670	acc=0.8703	4760.9 examples/second
# [Step=1350]	Loss=0.3615	acc=0.8720	4734.3 examples/second
# Test Loss=0.5468, Test acc=0.8297
#
# Epoch: 7
# [Step=1400]	Loss=0.3476	acc=0.8777	486.4 examples/second
# [Step=1450]	Loss=0.3571	acc=0.8744	4757.2 examples/second
# [Step=1500]	Loss=0.3511	acc=0.8766	4752.5 examples/second
# [Step=1550]	Loss=0.3517	acc=0.8769	4739.9 examples/second
# Test Loss=0.5212, Test acc=0.8429
# Saving...
#
# Epoch: 8
# [Step=1600]	Loss=0.3394	acc=0.8826	481.4 examples/second
# [Step=1650]	Loss=0.3359	acc=0.8815	4771.9 examples/second
# [Step=1700]	Loss=0.3368	acc=0.8815	4740.3 examples/second
# [Step=1750]	Loss=0.3388	acc=0.8811	4743.6 examples/second
# Test Loss=0.5525, Test acc=0.8278
#
# Epoch: 9
# [Step=1800]	Loss=0.3299	acc=0.8856	489.9 examples/second
# [Step=1850]	Loss=0.3244	acc=0.8859	4747.1 examples/second
# [Step=1900]	Loss=0.3231	acc=0.8868	4757.3 examples/second
# [Step=1950]	Loss=0.3250	acc=0.8859	4737.4 examples/second
# Test Loss=0.5054, Test acc=0.8430
# Saving...
#
# Epoch: 10
# [Step=2000]	Loss=0.3192	acc=0.8883	491.9 examples/second
# [Step=2050]	Loss=0.3191	acc=0.8890	4717.9 examples/second
# [Step=2100]	Loss=0.3213	acc=0.8879	4722.3 examples/second
# [Step=2150]	Loss=0.3213	acc=0.8885	4721.1 examples/second
# Test Loss=0.5354, Test acc=0.8308
#
# Epoch: 11
# [Step=2200]	Loss=0.3237	acc=0.8873	481.5 examples/second
# [Step=2250]	Loss=0.3182	acc=0.8870	4739.6 examples/second
# [Step=2300]	Loss=0.3139	acc=0.8883	4738.7 examples/second
# [Step=2350]	Loss=0.3125	acc=0.8897	4743.2 examples/second
# Test Loss=0.5446, Test acc=0.8353
#
# Epoch: 12
# [Step=2400]	Loss=0.2998	acc=0.8942	380.3 examples/second
# [Step=2450]	Loss=0.3056	acc=0.8918	4723.3 examples/second
# [Step=2500]	Loss=0.3040	acc=0.8925	4733.8 examples/second
# Test Loss=0.5144, Test acc=0.8463
# Saving...
#
# Epoch: 13
# [Step=2550]	Loss=0.2729	acc=0.8965	379.3 examples/second
# [Step=2600]	Loss=0.2939	acc=0.8927	4710.1 examples/second
# [Step=2650]	Loss=0.3033	acc=0.8917	4758.6 examples/second
# [Step=2700]	Loss=0.3059	acc=0.8902	4732.4 examples/second
# Test Loss=0.4958, Test acc=0.8441
#
# Epoch: 14
# [Step=2750]	Loss=0.3005	acc=0.8958	474.2 examples/second
# [Step=2800]	Loss=0.2987	acc=0.8929	4720.4 examples/second
# [Step=2850]	Loss=0.2995	acc=0.8926	4693.2 examples/second
# [Step=2900]	Loss=0.3018	acc=0.8918	4693.6 examples/second
# Test Loss=0.4992, Test acc=0.8454
#
# Epoch: 15
# [Step=2950]	Loss=0.3015	acc=0.8934	474.3 examples/second
# [Step=3000]	Loss=0.2889	acc=0.8970	4757.3 examples/second
# [Step=3050]	Loss=0.2943	acc=0.8963	4740.8 examples/second
# [Step=3100]	Loss=0.2950	acc=0.8958	4737.7 examples/second
# Test Loss=0.4878, Test acc=0.8530
# Saving...
#
# Epoch: 16
# [Step=3150]	Loss=0.2793	acc=0.9004	492.9 examples/second
# [Step=3200]	Loss=0.2760	acc=0.9018	4739.5 examples/second
# [Step=3250]	Loss=0.2879	acc=0.8992	4755.6 examples/second
# [Step=3300]	Loss=0.2873	acc=0.8993	4718.6 examples/second
# Test Loss=0.4631, Test acc=0.8554
# Saving...
#
# Epoch: 17
# [Step=3350]	Loss=0.2879	acc=0.9008	476.5 examples/second
# [Step=3400]	Loss=0.2836	acc=0.9005	4744.2 examples/second
# [Step=3450]	Loss=0.2857	acc=0.8997	4740.5 examples/second
# [Step=3500]	Loss=0.2844	acc=0.8998	4740.5 examples/second
# Test Loss=0.5056, Test acc=0.8515
#
# Epoch: 18
# [Step=3550]	Loss=0.2821	acc=0.9013	468.2 examples/second
# [Step=3600]	Loss=0.2887	acc=0.8991	4751.1 examples/second
# [Step=3650]	Loss=0.2876	acc=0.8989	4747.5 examples/second
# [Step=3700]	Loss=0.2867	acc=0.8998	4731.5 examples/second
# Test Loss=0.4659, Test acc=0.8530
#
# Epoch: 19
# [Step=3750]	Loss=0.2824	acc=0.8992	499.0 examples/second
# [Step=3800]	Loss=0.2835	acc=0.8993	4756.2 examples/second
# [Step=3850]	Loss=0.2786	acc=0.9003	4740.7 examples/second
# [Step=3900]	Loss=0.2772	acc=0.9007	4733.6 examples/second
# Test Loss=0.4486, Test acc=0.8591
# Saving...
# Files already downloaded and verified
# Test Loss=0.4486, Test accuracy=0.8591

# %% [markdown]
# ### Lab3 (d) Quantize pruned model

# %%
# Define quantized model and load weight
#Nbits = 4 #Change this value to finish (d)
#Nbits = 3
Nbits = 2

net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
net = net.to(device)
net.load_state_dict(torch.load("net_after_global_iterative_prune.pt"))
test(net)
# Out:
# Files already downloaded and verified
# Test Loss=7.1126, Test accuracy=0.1026

# %%
# Quantized model finetuning
finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)

# Load the model with best accuracy
net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
test(net)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=2.3067	acc=0.1448	526.2 examples/second
# [Step=100]	Loss=2.2477	acc=0.1556	4769.3 examples/second
# [Step=150]	Loss=2.2232	acc=0.1618	4745.9 examples/second
# Test Loss=2.1521, Test acc=0.1685
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=2.1340	acc=0.1865	466.3 examples/second
# [Step=250]	Loss=2.1438	acc=0.1861	4737.6 examples/second
# [Step=300]	Loss=2.1393	acc=0.1899	4754.3 examples/second
# [Step=350]	Loss=2.1316	acc=0.1978	4760.6 examples/second
# Test Loss=2.1157, Test acc=0.2055
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=2.1095	acc=0.2129	467.4 examples/second
# [Step=450]	Loss=2.1014	acc=0.2201	4773.0 examples/second
# [Step=500]	Loss=2.1010	acc=0.2207	4763.3 examples/second
# [Step=550]	Loss=2.0972	acc=0.2229	4755.7 examples/second
# Test Loss=2.0938, Test acc=0.2316
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=2.0955	acc=0.2292	477.2 examples/second
# [Step=650]	Loss=2.0799	acc=0.2315	4755.5 examples/second
# [Step=700]	Loss=2.0793	acc=0.2334	4738.4 examples/second
# [Step=750]	Loss=2.0732	acc=0.2381	4753.4 examples/second
# Test Loss=2.0638, Test acc=0.2495
# Saving...
#
# Epoch: 4
# [Step=800]	Loss=2.0558	acc=0.2529	457.7 examples/second
# [Step=850]	Loss=2.0560	acc=0.2465	4754.0 examples/second
# [Step=900]	Loss=2.0525	acc=0.2493	4751.6 examples/second
# [Step=950]	Loss=2.0464	acc=0.2524	4720.4 examples/second
# Test Loss=2.0444, Test acc=0.2579
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=2.0296	acc=0.2566	466.1 examples/second
# [Step=1050]	Loss=2.0301	acc=0.2576	4764.0 examples/second
# [Step=1100]	Loss=2.0281	acc=0.2600	4748.1 examples/second
# [Step=1150]	Loss=2.0247	acc=0.2614	4745.9 examples/second
# Test Loss=2.0387, Test acc=0.2625
# Saving...
#
# Epoch: 6
# [Step=1200]	Loss=2.0174	acc=0.2539	475.6 examples/second
# [Step=1250]	Loss=2.0096	acc=0.2605	4751.6 examples/second
# [Step=1300]	Loss=2.0090	acc=0.2640	4734.1 examples/second
# [Step=1350]	Loss=2.0038	acc=0.2672	4736.1 examples/second
# Test Loss=1.9998, Test acc=0.2780
# Saving...
#
# Epoch: 7
# [Step=1400]	Loss=2.0050	acc=0.2683	475.3 examples/second
# [Step=1450]	Loss=1.9948	acc=0.2683	4745.9 examples/second
# [Step=1500]	Loss=1.9887	acc=0.2704	4742.4 examples/second
# [Step=1550]	Loss=1.9877	acc=0.2704	4746.4 examples/second
# Test Loss=2.0063, Test acc=0.2705
#
# Epoch: 8
# [Step=1600]	Loss=1.9779	acc=0.2710	472.3 examples/second
# [Step=1650]	Loss=1.9765	acc=0.2744	4737.2 examples/second
# [Step=1700]	Loss=1.9746	acc=0.2734	4736.6 examples/second
# [Step=1750]	Loss=1.9691	acc=0.2754	4746.7 examples/second
# Test Loss=1.9982, Test acc=0.2708
#
# Epoch: 9
# [Step=1800]	Loss=1.9625	acc=0.2762	478.0 examples/second
# [Step=1850]	Loss=1.9560	acc=0.2765	4742.2 examples/second
# [Step=1900]	Loss=1.9537	acc=0.2781	4739.7 examples/second
# [Step=1950]	Loss=1.9499	acc=0.2801	4756.0 examples/second
# Test Loss=1.9886, Test acc=0.2661
#
# Epoch: 10
# [Step=2000]	Loss=1.9349	acc=0.2935	408.3 examples/second
# [Step=2050]	Loss=1.9337	acc=0.2900	4743.2 examples/second
# [Step=2100]	Loss=1.9319	acc=0.2895	4732.2 examples/second
# [Step=2150]	Loss=1.9311	acc=0.2899	4741.1 examples/second
# Test Loss=1.9329, Test acc=0.2933
# Saving...
#
# Epoch: 11
# [Step=2200]	Loss=1.9178	acc=0.2860	478.1 examples/second
# [Step=2250]	Loss=1.9187	acc=0.2898	4728.3 examples/second
# [Step=2300]	Loss=1.9167	acc=0.2938	4738.2 examples/second
# [Step=2350]	Loss=1.9144	acc=0.2943	4741.1 examples/second
# Test Loss=2.0547, Test acc=0.2217
#
# Epoch: 12
# [Step=2400]	Loss=1.8942	acc=0.3029	471.6 examples/second
# [Step=2450]	Loss=1.8941	acc=0.3010	4763.0 examples/second
# [Step=2500]	Loss=1.8910	acc=0.3010	4747.8 examples/second
# Test Loss=1.8906, Test acc=0.3081
# Saving...
#
# Epoch: 13
# [Step=2550]	Loss=1.9550	acc=0.2598	469.1 examples/second
# [Step=2600]	Loss=1.8796	acc=0.3045	4728.9 examples/second
# [Step=2650]	Loss=1.8647	acc=0.3066	4756.9 examples/second
# [Step=2700]	Loss=1.8679	acc=0.3064	4750.5 examples/second
# Test Loss=1.8922, Test acc=0.3032
#
# Epoch: 14
# [Step=2750]	Loss=1.8542	acc=0.3145	479.0 examples/second
# [Step=2800]	Loss=1.8428	acc=0.3125	4753.0 examples/second
# [Step=2850]	Loss=1.8449	acc=0.3143	4741.1 examples/second
# [Step=2900]	Loss=1.8403	acc=0.3159	4736.7 examples/second
# Test Loss=1.8791, Test acc=0.2908
#
# Epoch: 15
# [Step=2950]	Loss=1.8147	acc=0.3332	472.2 examples/second
# [Step=3000]	Loss=1.8205	acc=0.3204	4742.0 examples/second
# [Step=3050]	Loss=1.8153	acc=0.3230	4723.5 examples/second
# [Step=3100]	Loss=1.8133	acc=0.3229	4742.8 examples/second
# Test Loss=1.8347, Test acc=0.3080
#
# Epoch: 16
# [Step=3150]	Loss=1.7896	acc=0.3290	475.5 examples/second
# [Step=3200]	Loss=1.7966	acc=0.3248	4755.8 examples/second
# [Step=3250]	Loss=1.7954	acc=0.3261	4749.2 examples/second
# [Step=3300]	Loss=1.7902	acc=0.3271	4749.0 examples/second
# Test Loss=1.8762, Test acc=0.2942
#
# Epoch: 17
# [Step=3350]	Loss=1.7741	acc=0.3340	363.0 examples/second
# [Step=3400]	Loss=1.7788	acc=0.3297	4743.7 examples/second
# [Step=3450]	Loss=1.7782	acc=0.3300	4738.8 examples/second
# [Step=3500]	Loss=1.7741	acc=0.3313	4729.5 examples/second
# Test Loss=1.7626, Test acc=0.3342
# Saving...
#
# Epoch: 18
# [Step=3550]	Loss=1.7557	acc=0.3443	471.0 examples/second
# [Step=3600]	Loss=1.7528	acc=0.3415	4749.9 examples/second
# [Step=3650]	Loss=1.7598	acc=0.3356	4730.7 examples/second
# [Step=3700]	Loss=1.7546	acc=0.3387	4742.3 examples/second
# Test Loss=1.7465, Test acc=0.3314
#
# Epoch: 19
# [Step=3750]	Loss=1.7271	acc=0.3478	469.7 examples/second
# [Step=3800]	Loss=1.7432	acc=0.3390	4740.2 examples/second
# [Step=3850]	Loss=1.7460	acc=0.3358	4732.4 examples/second
# [Step=3900]	Loss=1.7451	acc=0.3402	4741.1 examples/second
# Test Loss=1.7771, Test acc=0.3254
# Files already downloaded and verified
# Test Loss=1.7626, Test accuracy=0.3342

# %% [markdown]
# ### Lab3 (e) Prune quantized model

# %%
net = ResNetCIFAR(num_layers=20, Nbits=4)
net = net.to(device)

net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    q=(epoch+1)*8
    
    net.train()
    # Increase model sparsity
    if epoch<10:
        global_prune_by_percentage(net, q=q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer)
    
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))
    
    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "quantized_net_after_global_iterative_prune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.0627	acc=0.9788	526.0 examples/second
# [Step=100]	Loss=0.0647	acc=0.9784	4842.0 examples/second
# [Step=150]	Loss=0.0661	acc=0.9777	4820.4 examples/second
# Test Loss=0.3388, Test acc=0.9083
#
# Epoch: 1
# [Step=50]	Loss=0.0714	acc=0.9727	547.6 examples/second
# [Step=100]	Loss=0.0688	acc=0.9751	4858.8 examples/second
# [Step=150]	Loss=0.0693	acc=0.9752	4847.4 examples/second
# Test Loss=0.3446, Test acc=0.9080
#
# Epoch: 2
# [Step=50]	Loss=0.0709	acc=0.9758	552.1 examples/second
# [Step=100]	Loss=0.0706	acc=0.9754	4853.7 examples/second
# [Step=150]	Loss=0.0706	acc=0.9756	4829.8 examples/second
# Test Loss=0.3470, Test acc=0.9067
#
# Epoch: 3
# [Step=50]	Loss=0.0773	acc=0.9724	548.9 examples/second
# [Step=100]	Loss=0.0755	acc=0.9735	4832.0 examples/second
# [Step=150]	Loss=0.0755	acc=0.9738	4846.3 examples/second
# Test Loss=0.3469, Test acc=0.9067
#
# Epoch: 4
# [Step=50]	Loss=0.0781	acc=0.9730	557.0 examples/second
# [Step=100]	Loss=0.0825	acc=0.9712	4838.9 examples/second
# [Step=150]	Loss=0.0837	acc=0.9707	4824.6 examples/second
# Test Loss=0.3454, Test acc=0.9054
#
# Epoch: 5
# [Step=50]	Loss=0.0923	acc=0.9684	548.6 examples/second
# [Step=100]	Loss=0.0958	acc=0.9663	4830.1 examples/second
# [Step=150]	Loss=0.0957	acc=0.9666	4836.2 examples/second
# Test Loss=0.3596, Test acc=0.8992
#
# Epoch: 6
# [Step=50]	Loss=0.1248	acc=0.9552	552.1 examples/second
# [Step=100]	Loss=0.1255	acc=0.9549	4818.7 examples/second
# [Step=150]	Loss=0.1265	acc=0.9549	4829.4 examples/second
# Test Loss=0.3684, Test acc=0.8914
#
# Epoch: 7
# [Step=50]	Loss=0.1879	acc=0.9330	554.1 examples/second
# [Step=100]	Loss=0.1847	acc=0.9346	4841.4 examples/second
# [Step=150]	Loss=0.1865	acc=0.9342	4819.6 examples/second
# Test Loss=0.3927, Test acc=0.8782
#
# Epoch: 8
# [Step=50]	Loss=0.3361	acc=0.8830	540.7 examples/second
# [Step=100]	Loss=0.3325	acc=0.8840	4828.9 examples/second
# [Step=150]	Loss=0.3285	acc=0.8851	4828.7 examples/second
# Test Loss=0.4861, Test acc=0.8420
#
# Epoch: 9
# [Step=50]	Loss=0.6831	acc=0.7666	538.0 examples/second
# [Step=100]	Loss=0.6893	acc=0.7637	4814.2 examples/second
# [Step=150]	Loss=0.6874	acc=0.7638	4804.6 examples/second
# Test Loss=0.7863, Test acc=0.7455
#
# Epoch: 10
# [Step=50]	Loss=0.6895	acc=0.7639	547.5 examples/second
# [Step=100]	Loss=0.6839	acc=0.7655	4820.9 examples/second
# [Step=150]	Loss=0.6862	acc=0.7652	4807.4 examples/second
# Test Loss=0.7748, Test acc=0.7479
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=0.6925	acc=0.7605	547.7 examples/second
# [Step=100]	Loss=0.6809	acc=0.7652	4811.9 examples/second
# [Step=150]	Loss=0.6831	acc=0.7658	4809.1 examples/second
# Test Loss=0.7847, Test acc=0.7437
#
# Epoch: 12
# [Step=50]	Loss=0.6967	acc=0.7566	551.5 examples/second
# [Step=100]	Loss=0.6916	acc=0.7623	4772.3 examples/second
# [Step=150]	Loss=0.6859	acc=0.7634	4810.1 examples/second
# Test Loss=0.7774, Test acc=0.7475
#
# Epoch: 13
# [Step=50]	Loss=0.6907	acc=0.7634	553.6 examples/second
# [Step=100]	Loss=0.6915	acc=0.7647	4806.4 examples/second
# [Step=150]	Loss=0.6870	acc=0.7665	4806.3 examples/second
# Test Loss=0.7792, Test acc=0.7466
#
# Epoch: 14
# [Step=50]	Loss=0.7014	acc=0.7555	544.5 examples/second
# [Step=100]	Loss=0.6926	acc=0.7596	4799.2 examples/second
# [Step=150]	Loss=0.6801	acc=0.7659	4809.8 examples/second
# Test Loss=0.7898, Test acc=0.7434
#
# Epoch: 15
# [Step=50]	Loss=0.6812	acc=0.7647	410.4 examples/second
# [Step=100]	Loss=0.6812	acc=0.7652	4786.4 examples/second
# [Step=150]	Loss=0.6783	acc=0.7669	4765.4 examples/second
# Test Loss=0.7796, Test acc=0.7460
#
# Epoch: 16
# [Step=50]	Loss=0.6965	acc=0.7580	552.7 examples/second
# [Step=100]	Loss=0.6889	acc=0.7637	4819.5 examples/second
# [Step=150]	Loss=0.6828	acc=0.7659	4797.9 examples/second
# Test Loss=0.7832, Test acc=0.7449
#
# Epoch: 17
# [Step=50]	Loss=0.6777	acc=0.7669	548.7 examples/second
# [Step=100]	Loss=0.6832	acc=0.7645	4812.5 examples/second
# [Step=150]	Loss=0.6804	acc=0.7660	4814.1 examples/second
# Test Loss=0.7855, Test acc=0.7449
#
# Epoch: 18
# [Step=50]	Loss=0.6879	acc=0.7673	551.6 examples/second
# [Step=100]	Loss=0.6863	acc=0.7659	4804.7 examples/second
# [Step=150]	Loss=0.6833	acc=0.7665	4809.1 examples/second
# Test Loss=0.7871, Test acc=0.7442
#
# Epoch: 19
# [Step=50]	Loss=0.6877	acc=0.7606	537.7 examples/second
# [Step=100]	Loss=0.6856	acc=0.7629	4806.7 examples/second
# [Step=150]	Loss=0.6810	acc=0.7650	4798.6 examples/second
# Test Loss=0.7861, Test acc=0.7449

# %%
net.load_state_dict(torch.load("quantized_net_after_global_iterative_prune.pt"))

zeros_sum = 0
total_sum = 0
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        np_weight = layer.weight.data.cpu().numpy()
        zeros = (np_weight==0).sum()
        total = np_weight.flatten().shape[0]
        zeros_sum+=zeros
        total_sum+=total
        print('Sparsity of '+name+': '+str(zeros/total))
print('Total sparsity of: '+str(zeros_sum/total_sum))
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.30787037037037035
# Sparsity of body_op.0.conv1.0.conv: 0.6575520833333334
# Sparsity of body_op.0.conv2.0.conv: 0.6397569444444444
# Sparsity of body_op.1.conv1.0.conv: 0.6280381944444444
# Sparsity of body_op.1.conv2.0.conv: 0.6488715277777778
# Sparsity of body_op.2.conv1.0.conv: 0.6315104166666666
# Sparsity of body_op.2.conv2.0.conv: 0.6684027777777778
# Sparsity of body_op.3.conv1.0.conv: 0.6252170138888888
# Sparsity of body_op.3.conv2.0.conv: 0.6882595486111112
# Sparsity of body_op.4.conv1.0.conv: 0.7261284722222222
# Sparsity of body_op.4.conv2.0.conv: 0.7820095486111112
# Sparsity of body_op.5.conv1.0.conv: 0.7249348958333334
# Sparsity of body_op.5.conv2.0.conv: 0.8132595486111112
# Sparsity of body_op.6.conv1.0.conv: 0.7331814236111112
# Sparsity of body_op.6.conv2.0.conv: 0.7640245225694444
# Sparsity of body_op.7.conv1.0.conv: 0.7770724826388888
# Sparsity of body_op.7.conv2.0.conv: 0.8261176215277778
# Sparsity of body_op.8.conv1.0.conv: 0.8527018229166666
# Sparsity of body_op.8.conv2.0.conv: 0.9764539930555556
# Sparsity of final_fc.linear: 0.159375
# Total sparsity of: 0.8000007453342078
# Files already downloaded and verified
# Test Loss=0.7748, Test accuracy=0.7479
